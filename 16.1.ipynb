# %% [markdown]
# #### 16.1 Die elektrische Ladung
#
# * Eigenschaften von einigen Elementarteilchen (zusätzlich zur Masse)
# * Ladung is Ursprung der elektromagnetischen Wechselwirkung
# * zwei Arten von Ladungen (positiv und negativ)
# * Ladung ist gequantelt
#   nur ganzahlige Vielfache der Elementarladung, wird in Coulomb  gemessen.
#
# $$e = 1.602\cdot 10^{-19}\mathrm{C}$$
#
# * Ladung des Elektrons $Q_e = -e $
#
# * Ladung des Protons $Q_e = e $
#
# * Identität nachgewiesen: $\left|Q_e\right|=\left|Q_p\right|$
#
# * Satz der Ladungserhaltung
#
# <center>Die Gesamtladung in einem abgeschlossenen System bleibt erhalten</center>
#
# <center>aber ich kann Ladungen trennen.</center>

# %% [markdown]
# #### Demonstration der Induktion von Ladungen im Nichtleiter

# %%
# %matplotlib notebook
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, figsize=(5, 5))

x = np.arange(-5, 5, 1.)
y = np.arange(-5, 5, 1.)
xx, yy = np.meshgrid(x, y)

def f(dist):
    ax.clear()
    ax.plot(xx,yy,'r+',markersize=14)
    ax.plot(xx+dist,yy+0.1,'b_',markersize=14)
    ax.set_xlim(-7.,7.)
    ax.set_ylim(-7,7.)
    ax.axes.get_xaxis().set_ticks([])
    ax.axes.get_yaxis().set_ticks([])
    plt.tight_layout()
    plt.show()
    return 

dist = widgets.FloatSlider(min=-1, max=1, value=0, step = 0.1)
widgets.interactive(f, dist=dist)
# Out:
# <img src="data:image/png;base64,..." width="500">
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEZsb2F0U2xpZGVyKHZhbHVlPTAuMCwgZGVzY3JpcHRpb249dSdkaXN0JywgbWF4PTEuMCwgbWluPS0xLjApLCBPdXRwdXQoKSksIF9kb21fY2xhc3Nlcz3igKY=

# %% [markdown]
# #### Otto von Guerickes Schwefelkugel
#
# <img src="figures/16.1_1.png" alt="16.1_1.png" style="width: 550px;"/>
